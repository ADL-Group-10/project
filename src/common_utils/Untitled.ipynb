# %%
from src.common_utils import load_config, get_paths, set_seed, get_device, get_logger
cfg = load_config()
print(cfg.project.name)   # should print: nvd-snow-yolov9
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.common_utils import load_config, get_paths, set_seed, get_device, get_logger
#       2 cfg = load_config()
#       3 print(cfg.project.name)   # should print: nvd-snow-yolov9
#
# ModuleNotFoundError: No module named 'src'
